# %% [markdown]
# ## World Population Data

# %%
import pandas as pd

# %%
file_path = r"..\data_files\json_files\new_pop.json"
df = pd.read_json(file_path)

df.head(20)

df.to_csv(r"..\data_files\csv_files\world_pop.csv", index=False)

# %%
df['Country'].nunique()
# Out:
# 233
